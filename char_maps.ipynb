# %%
to_int = lambda str_in: 0 if ((len(str_in) == 0) | (str_in == "0")) else (2*(int(str_in[:1])))**(len(str_in) - 1) + to_int(str_in[1:])

# %%
charmap = {
    'G' : [
    "00111100",
    "01100110",
    "01100000",
    "01101110",
    "01100110",
    "01100110",
    "00111100",
    "00000000",
],
    'A' : [
    "00011000",
    "00111100",
    "01100110",
    "01111110",
    "01100110",
    "01100110",
    "01100110",
    "00000000",
],
    
'M' : [
    "01100011",
    "01110111",
    "01111111",
    "01101011",
    "01100011",
    "01100011",
    "01100011",
    "00000000",
],
    
'E' : [
    "01111110",
    "01100000",
    "01100000",    
    "01111000",
    "01100000",
    "01100000",    
    "01111110",
    "00000000"
],
 
    
    
'O' : [
    "00111100",
    "01100110",
    "01100110",    
    "01100110",
    "01100110",
    "01100110",    
    "00111100",
    "00000000"
],
    
    
'V' : [
    "01100110",
    "01100110",
    "01100110",    
    "01100110",
    "01100110",
    "00111100",    
    "00011000",
    "00000000"
],

    'R' : [
    "01111100",
    "01100110",
    "01100110",    
    "01111100",
    "01111000",
    "01101100",    
    "01100110",
    "00000000"
],    
    
    
    'J' : [
        "00111110",
        "00001100",
        "00001100",
        "00001100",
        "00001100",
        "01101100",
        "00111000",
        "00000000"
    ],
    
    'S' : [
        "00111100",
        "01100110",
        "01100000",
        "00111100",
        "00000110",
        "01100110",
        "00111100",
        "00000000", 
    ],
    
    'N' : [
        "01100110",
        "01110110",
        "01111110",
        "01111110",
        "01101110",
        "01100110",
        "01100110",
        "00000000"
    ],
    
    'K': [
        "01100110",
        "01101100",
        "01111000",
        "01110000",
        "01111000",
        "01101100",
        "01100110",
        "00000000"
    ],
    
    'T' : [
        "01111110",
        "00011000",
        "00011000",
        "00011000",
        "00011000",
        "00011000",
        "00011000",
        "00000000"
    ],
    
    'H' : [
        "01100110",
        "01100110",
        "01100110",
        "01111110",
        "01100110",
        "01100110",
        "01100110",
        "00000000"
    ],
    
    'Y' : [
        "01100110",
        "01100110",
        "01100110",
        "00111100",
        "00011000",
        "00011000",
        "00011000",
        "00000000"       
    ],
    
    'HEART' : [
        "00110110",
        "01111111",
        "01111111",
        "01111111",
        "00111110",
        "00011100",
        "00001000",
        "00000000"
    ],
    
    'D' : [
        "01111000",
        "01101100",
        "01100110",
        "01100110",
        "01100110",
        "01101100",
        "01111000",
        "00000000"
    ],
    
    'I' : [
        "00111100",
        "00011000",
        "00011000",
        "00011000",
        "00011000",
        "00011000",
        "00111100",
        "00000000"
    ],
    
    'C' : [
        "00111100",
        "01100110",
        "01100000",
        "01100000",
        "01100000",
        "01100110",
        "00111100",
        "00000000"
    ],
    
    'SML' : [
        "00111100",
        "01000010",
        "10100101",
        "10000001",
        "10100101",
        "10011001",
        "01000010",
        "00111100"
    ]
}

# %%
for key in charmap.keys():
    vals = [str(to_int(charmap[key][i])) for i in range(8)]
    print("{{{0}}}, //{1}".format(','.join(vals), key))
# Out:
# {60,102,96,110,102,102,60,0}, //G
# {24,60,102,126,102,102,102,0}, //A
# {99,119,127,107,99,99,99,0}, //M
# {126,96,96,120,96,96,126,0}, //E
# {60,102,102,102,102,102,60,0}, //O
# {102,102,102,102,102,60,24,0}, //V
# {124,102,102,124,120,108,102,0}, //R
# {62,12,12,12,12,108,56,0}, //J
# {60,102,96,60,6,102,60,0}, //S
# {102,118,126,126,110,102,102,0}, //N
# {102,108,120,112,120,108,102,0}, //K
# {126,24,24,24,24,24,24,0}, //T
# {102,102,102,126,102,102,102,0}, //H
# {102,102,102,60,24,24,24,0}, //Y
# {54,127,127,127,62,28,8,0}, //HEART
# {120,108,102,102,102,108,120,0}, //D
# {60,24,24,24,24,24,60,0}, //I
# {60,102,96,96,96,102,60,0}, //C
# {60,66,165,129,165,153,66,60}, //SML
